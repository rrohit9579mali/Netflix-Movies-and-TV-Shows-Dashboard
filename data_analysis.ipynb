# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as scn

# %%
df=pd.read_csv('Data_Set/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['director'].isnull().sum()
# Out:
# np.int64(2634)

# %%
df['director']=df['director'].fillna('Unknown')
df['cast']=df['cast'].fillna('"Not Available')
df['country']=df['country'].fillna('Unknown')
df.dropna(subset=['date_added','rating','duration'], inplace=True)

# %%
df = pd.read_csv('Data_Set/clean_netflix_titles.csv', header=1)

# %%
total_movie=df.groupby('Movie')['0'].count().values[0]
total_tv_show=df.groupby('Movie')['0'].count().values[1]
total_movie
# Out:
# np.int64(6125)

# %%
total_tv_show
# Out:
# np.int64(2664)

# %%
df['Movie'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# Out:
#    0  s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 0  1  s2  TV Show          Blood & Water          Unknown
# 1  2  s3  TV Show              Ganglands  Julien Leclercq
# 2  3  s4  TV Show  Jailbirds New Orleans          Unknown
# 3  4  s5  TV Show           Kota Factory          Unknown
# 4  5  s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                       "Not Available United States  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...       Unknown
# 2                                     "Not Available       Unknown
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...       Unknown
#
#    September 25, 2021  2020  PG-13     90 min  \
# 0  September 24, 2021  2021  TV-MA  2 Seasons
# 1  September 24, 2021  2021  TV-MA   1 Season
# 2  September 24, 2021  2021  TV-MA   1 Season
# ...

# %%
# Bar Chart – Top 10 countries with most content
df.rename(columns={'Dick Johnson Is Dead':'title'},inplace=True)

# %%
df.rename(columns={'Movie':'type'},inplace=True)

# %%
df.rename(columns={'Kirsten Johnson':'director'},inplace=True)

# %%
df.rename(columns={'"Not Available':'cast'},inplace=True)

# %%
df.rename(columns={'United States':'country'},inplace=True)

# %%
df.rename(columns={'September 25, 2021':'date'},inplace=True)

# %%
df.rename(columns={'September 25, 2021':'date'},inplace=True)

# %%
df.rename(columns={'2020':'year'},inplace=True)

# %%
df.rename(columns={'PG-13':'rating'},inplace=True)

# %%
df.head(1)
# Out:
#    0  s1     type          title director  \
# 0  1  s2  TV Show  Blood & Water  Unknown
#
#                                                 cast       country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#                  date  year rating     90 min  \
# 0  September 24, 2021  2021  TV-MA  2 Seasons
#
#                                      Documentaries  \
# 0  International TV Shows, TV Dramas, TV Mysteries
#
#   As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.
# 0  After crossing paths at a party, a Cape Town t...

# %%
	duration	listed_in	description
# Out:
#   Cell In[234], line 1
#     duration	listed_in	description
#             	^
# SyntaxError: invalid syntax

# %%
df.rename(columns={'90 min':'duration'},inplace=True)
df.rename(columns={'Documentaries':'listed_in'},inplace=True)
df.rename(columns={'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.':'description'},inplace=True)

# %%
df
# Out:
#          0     s1     type                  title         director  \
# 0        1     s2  TV Show          Blood & Water          Unknown
# 1        2     s3  TV Show              Ganglands  Julien Leclercq
# 2        3     s4  TV Show  Jailbirds New Orleans          Unknown
# 3        4     s5  TV Show           Kota Factory          Unknown
# 4        5     s6  TV Show          Midnight Mass    Mike Flanagan
# ...    ...    ...      ...                    ...              ...
# 8784  8802  s8803    Movie                 Zodiac    David Fincher
# 8785  8803  s8804  TV Show            Zombie Dumb          Unknown
# 8786  8804  s8805    Movie             Zombieland  Ruben Fleischer
# 8787  8805  s8806    Movie                   Zoom     Peter Hewitt
# 8788  8806  s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.to_csv('clean_netflix_titles.csv', index=False, header=True)

# %%
pd.read_csv('')
# Out:
#       Unnamed: 0     0     s1     type                  title  \
# 0              0     1     s2  TV Show          Blood & Water
# 1              1     2     s3  TV Show              Ganglands
# 2              2     3     s4  TV Show  Jailbirds New Orleans
# 3              3     4     s5  TV Show           Kota Factory
# 4              4     5     s6  TV Show          Midnight Mass
# ...          ...   ...    ...      ...                    ...
# 8784        8784  8802  s8803    Movie                 Zodiac
# 8785        8785  8803  s8804  TV Show            Zombie Dumb
# 8786        8786  8804  s8805    Movie             Zombieland
# 8787        8787  8805  s8806    Movie                   Zoom
# 8788        8788  8806  s8807    Movie                 Zubaan
#
#              director                                               cast  \
# 0             Unknown  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...
